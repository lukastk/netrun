# %% [markdown]
# # nodes.summarize
#
# Produces a summary and statistics for the transformed text.
# Has two output ports: `summary` and `stats`.

# %%
#|default_exp summarize
#|export_as_func true

# %%
#|set_func_signature
def main(text: str, ctx, print) -> {"summary": str, "stats": str}:
    """Produce a summary and statistics for the text."""
    ...

# %% [markdown]
# ## Dev setup
#
# `set_node_func_args` runs the full upstream chain (`fetch_text` -> `transform`)
# to produce realistic input for this node.

# %%
from netrun_utils.dev import set_node_func_args, show_node_vars
from pathlib import Path

config_path = Path("../..") / "main.netrun.json"
set_node_func_args("summarize", config_path)
show_node_vars("summarize", config_path)
# Out:
# No cached data. Running upstream to get inputs for 'summarize'...
#   [epoch start] fetch_text
# [15:42:46.458] [fetch_text] Fetching text from source: greeting
# [15:42:46.458] [fetch_text] Fetching text | source=greeting
# [15:42:46.513] [fetch_text] Fetch complete | length=50
# [15:42:46.514] [fetch_text] Fetched 50 characters
#   [epoch end]   fetch_text (success, 59ms)
#   [epoch start] transform
# [15:42:46.517] [transform] Transforming with mode=upper
# [15:42:46.517] [transform] Transforming | mode=upper input_length=50
# [15:42:46.518] [transform] Transform complete | output_length=50
# [15:42:46.518] [transform] Output: HELLO WORLD! THIS IS A SAMPLE TEXT FOR PROCESSING....
#   [epoch end]   transform (success, 2ms)
# Injected: ctx, print, text
#
# Node variables for 'summarize':
# Name            Value       Type  Source
# ──────────────  ──────────  ────  ──────
# text_source     'greeting'  str   global
# transform_mode  'upper'     str   global

# %%
text  # Inspect: this is the transformed text from upstream
# Out:
# 'HELLO WORLD! THIS IS A SAMPLE TEXT FOR PROCESSING.'

# %% [markdown]
# ## Function body

# %%
#|export
print(f"Summarizing text of length {len(text)}")
ctx.log("Summarizing", input_length=len(text))
# Out:
# Summarizing text of length 50

# %%
#|export
word_count = len(text.split())
char_count = len(text)
summary = f"[{word_count} words] {text[:60]}..."
stats = f"chars={char_count}, words={word_count}, avg_word_len={char_count / max(word_count, 1):.1f}"

# %%
print(f"Summary: {summary}")
print(f"Stats: {stats}")
# Out:
# Summary: [9 words] HELLO WORLD! THIS IS A SAMPLE TEXT FOR PROCESSING....
# Stats: chars=50, words=9, avg_word_len=5.6

# %%
#|export
ctx.log("Summary complete", word_count=word_count, char_count=char_count)

# %%
#|export
{"summary": summary, "stats": stats} #|func_return_line
# Out:
# {'summary': '[9 words] HELLO WORLD! THIS IS A SAMPLE TEXT FOR PROCESSING....',
#  'stats': 'chars=50, words=9, avg_word_len=5.6'}
